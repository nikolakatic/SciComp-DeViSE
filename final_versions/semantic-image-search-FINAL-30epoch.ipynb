# %%
import os
import time
import numpy as np

# %%
def load_embeddings(embeddings_path):
    embeddings = {}
    with open(embeddings_path, 'r') as file:
        for line in file:
            splits = line.split()
            word = splits[0]
            coords = np.asarray(splits[1:], dtype='float32')
            embeddings[word] = coords
    return embeddings

# %%
word_embeddings = load_embeddings('./glove.6B.300d.txt')

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
def get_word_embedding(category, word_embeddings, wordvec_size=300):
    # Splitting multiword categories (e.g. potted_plants)
    vector = np.zeros(shape=wordvec_size)
    num_of_categories = 0
    for cat in category.split("_"):
        if cat in word_embeddings:
            vector += word_embeddings[cat]
            num_of_categories += 1
    if num_of_categories > 0:
        return vector / num_of_categories
    return vector

def preprocess_images(dataset_dir, word_embeddings, wordvec_size=300):
    image_list = []
    labels_list = []
    paths_list = []
    categories_list = []
    categories = os.listdir(dataset_dir)

    for category in categories:
        word_embedding = get_word_embedding(category, word_embeddings, wordvec_size)
        image_names = os.listdir(os.path.join(dataset_dir, category))

        for img_name in image_names:
            full_path = os.path.join(dataset_dir, category, img_name)

            img_pil = image.load_img(full_path, target_size=(224, 224))
            img_raw = image.img_to_array(img_pil)
            img = preprocess_input(img_raw) # VGG16 image preprocessing

            image_list.append(img)
            labels_list.append(word_embedding)
            paths_list.append(full_path)
            categories_list.append(category)

    return np.array(image_list), np.array(labels_list), paths_list, categories_list

# %%
images_vgg16, image_embeddings, image_paths, categories_list = \
    preprocess_images('./dataset', word_embeddings)

# %%
images_vgg16.shape
# Out:
# (1000, 224, 224, 3)

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, BatchNormalization, Activation, Dropout
from tensorflow.keras.losses import cosine_similarity

# %%
def hybrid_model_backbone(intermediate_dim=2000, word_embedding_dim=300):
    vgg16 = VGG16(input_shape=images_vgg16.shape[1:])
    x = vgg16.get_layer('fc2').output

    for layer in vgg16.layers:
        layer.trainable = False

    x = Dense(intermediate_dim, name="dense1")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(0.5)(x)

    x = Dense(word_embedding_dim, name="dense2")(x)
    outputs = BatchNormalization()(x)

    model = Model(inputs=[vgg16.input], outputs=outputs)
    # https://faroit.com/keras-docs/2.0.8/optimizers/
    sgd = optimizers.SGD(decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss=cosine_similarity)
    return model

# %%
hybrid_model = hybrid_model_backbone()

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
import json
import pandas as pd

# %%
def get_model_trained(model, X, Y, model_path, train_model=False):
    num_of_instances = X.shape[0]
    train_validation_size = 0.9

    X, Y = shuffle(X, Y, random_state=7)
    df = pd.DataFrame(data=X.reshape(num_of_instances, -1))

    # Split dataset for training_validation and testing
    X_train_validation, X_test, Y_train_validation, Y_test = \
        train_test_split(df, Y, train_size=train_validation_size, random_state=7)
    test_data = (X_test, Y_test)
    
    # On Thinkpad 480 (i7-8650u, 32GB of RAM, Nidia MX150) it takes 1h and 11mins
    if train_model: 
        epochs, batch_size = (30, 32)
        validation_size = 0.2

        # Convert remaining data back to numpy array
        num_of_train_validation_instances = int(train_validation_size*num_of_instances)
        X_train_validation_shape = (num_of_train_validation_instances,)+X.shape[1:]
        X_train_validation = X_train_validation.values.reshape(X_train_validation_shape)

        # Split dataset for training and validation        
        X_train, X_validation, Y_train, Y_validation = \
            train_test_split(X_train_validation, Y_train_validation, 
                             test_size=validation_size, random_state=7)
            
        # Train model (save history and checkpoint object)
        checkpointer = ModelCheckpoint(
            filepath='best.hdf5', verbose=1, save_best_only=True)
        history = model.fit(X_train, Y_train,
                            validation_data=(X_validation, Y_validation),
                            epochs=epochs,
                            batch_size=batch_size,
                            callbacks=[checkpointer])

        model.save(model_path)
        with open("history_30_epochs.json", 'w') as f:
            json.dump(history.history, f)
        return model, history.history, test_data

    # Assuming that there is a model in a given path.
    else:
        history = None
        with open("history.json", 'r') as f:
            history = json.loads(f.read())
        return load_model(model_path), history, test_data

# %%
hybrid_model, history, test_data = get_model_trained(hybrid_model, 
                                                     images_vgg16, 
                                                     image_embeddings, 
                                                     "./model_with_history_30_epochs", 
                                                     train_model=True)
# Out:
# Epoch 1/30
# 23/23 [==============================] - ETA: 0s - loss: -0.0241
# Epoch 00001: val_loss improved from inf to -0.08617, saving model to best.hdf5
# 23/23 [==============================] - 195s 8s/step - loss: -0.0241 - val_loss: -0.0862
# Epoch 2/30
# 23/23 [==============================] - ETA: 0s - loss: -0.1130
# Epoch 00002: val_loss improved from -0.08617 to -0.18656, saving model to best.hdf5
# 23/23 [==============================] - 147s 6s/step - loss: -0.1130 - val_loss: -0.1866
# Epoch 3/30
# 23/23 [==============================] - ETA: 0s - loss: -0.1943
# Epoch 00003: val_loss improved from -0.18656 to -0.26276, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.1943 - val_loss: -0.2628
# Epoch 4/30
# 23/23 [==============================] - ETA: 0s - loss: -0.2555
# Epoch 00004: val_loss improved from -0.26276 to -0.31807, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.2555 - val_loss: -0.3181
# Epoch 5/30
# 23/23 [==============================] - ETA: 0s - loss: -0.2999
# Epoch 00005: val_loss improved from -0.31807 to -0.35835, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.2999 - val_loss: -0.3583
# Epoch 6/30
# 23/23 [==============================] - ETA: 0s - loss: -0.3358
# Epoch 00006: val_loss improved from -0.35835 to -0.39021, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.3358 - val_loss: -0.3902
# Epoch 7/30
# 23/23 [==============================] - ETA: 0s - loss: -0.3613
# Epoch 00007: val_loss improved from -0.39021 to -0.41628, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.3613 - val_loss: -0.4163
# Epoch 8/30
# 23/23 [==============================] - ETA: 0s - loss: -0.3857
# Epoch 00008: val_loss improved from -0.41628 to -0.43712, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.3857 - val_loss: -0.4371
# Epoch 9/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4120
# Epoch 00009: val_loss improved from -0.43712 to -0.45493, saving model to best.hdf5
# 23/23 [==============================] - 174s 8s/step - loss: -0.4120 - val_loss: -0.4549
# Epoch 10/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4285
# Epoch 00010: val_loss improved from -0.45493 to -0.47141, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.4285 - val_loss: -0.4714
# Epoch 11/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4447
# Epoch 00011: val_loss improved from -0.47141 to -0.48620, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.4447 - val_loss: -0.4862
# Epoch 12/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4602
# Epoch 00012: val_loss improved from -0.48620 to -0.49849, saving model to best.hdf5
# 23/23 [==============================] - 141s 6s/step - loss: -0.4602 - val_loss: -0.4985
# Epoch 13/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4739
# Epoch 00013: val_loss improved from -0.49849 to -0.51020, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.4739 - val_loss: -0.5102
# Epoch 14/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4821
# Epoch 00014: val_loss improved from -0.51020 to -0.52147, saving model to best.hdf5
# 23/23 [==============================] - 140s 6s/step - loss: -0.4821 - val_loss: -0.5215
# Epoch 15/30
# 23/23 [==============================] - ETA: 0s - loss: -0.4996
# Epoch 00015: val_loss improved from -0.52147 to -0.53223, saving model to best.hdf5
# 23/23 [==============================] - 140s 6s/step - loss: -0.4996 - val_loss: -0.5322
# Epoch 16/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5059
# Epoch 00016: val_loss improved from -0.53223 to -0.54184, saving model to best.hdf5
# 23/23 [==============================] - 172s 7s/step - loss: -0.5059 - val_loss: -0.5418
# Epoch 17/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5198
# Epoch 00017: val_loss improved from -0.54184 to -0.55159, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5198 - val_loss: -0.5516
# Epoch 18/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5282
# Epoch 00018: val_loss improved from -0.55159 to -0.56015, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5282 - val_loss: -0.5602
# Epoch 19/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5391
# Epoch 00019: val_loss improved from -0.56015 to -0.56833, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.5391 - val_loss: -0.5683
# Epoch 20/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5483
# Epoch 00020: val_loss improved from -0.56833 to -0.57664, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.5483 - val_loss: -0.5766
# Epoch 21/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5541
# Epoch 00021: val_loss improved from -0.57664 to -0.58398, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5541 - val_loss: -0.5840
# Epoch 22/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5612
# Epoch 00022: val_loss improved from -0.58398 to -0.59135, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.5612 - val_loss: -0.5913
# Epoch 23/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5724
# Epoch 00023: val_loss improved from -0.59135 to -0.59752, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5724 - val_loss: -0.5975
# Epoch 24/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5770
# Epoch 00024: val_loss improved from -0.59752 to -0.60358, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5770 - val_loss: -0.6036
# Epoch 25/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5818
# Epoch 00025: val_loss improved from -0.60358 to -0.60952, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5818 - val_loss: -0.6095
# Epoch 26/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5908
# Epoch 00026: val_loss improved from -0.60952 to -0.61459, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.5908 - val_loss: -0.6146
# Epoch 27/30
# 23/23 [==============================] - ETA: 0s - loss: -0.5986
# Epoch 00027: val_loss improved from -0.61459 to -0.62012, saving model to best.hdf5
# 23/23 [==============================] - 138s 6s/step - loss: -0.5986 - val_loss: -0.6201
# Epoch 28/30
# 23/23 [==============================] - ETA: 0s - loss: -0.6042
# Epoch 00028: val_loss improved from -0.62012 to -0.62518, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.6042 - val_loss: -0.6252
# Epoch 29/30
# 23/23 [==============================] - ETA: 0s - loss: -0.6100
# Epoch 00029: val_loss improved from -0.62518 to -0.62940, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.6100 - val_loss: -0.6294
# Epoch 30/30
# 23/23 [==============================] - ETA: 0s - loss: -0.6142
# Epoch 00030: val_loss improved from -0.62940 to -0.63394, saving model to best.hdf5
# 23/23 [==============================] - 137s 6s/step - loss: -0.6142 - val_loss: -0.6339
# WARNING:tensorflow:From /home/irena/anaconda3/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./model_with_history_30_epochs/assets

# %%
import matplotlib.pyplot as plt
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %%
from annoy import AnnoyIndex

# %%
def get_annoy_index(vectors_list, number_of_trees=20, dims=300):
    annoy_index = AnnoyIndex(dims, 'angular')
    for i, vec in enumerate(vectors_list):
        annoy_index.add_item(i, vec)
    annoy_index.build(number_of_trees)
    return annoy_index

def generate_word_annoy_index(word_embeddings):
    word_index = dict(enumerate(word_embeddings))
    word_embeddings_list = [word_embeddings[word] for word in word_index.values()]
    annoy_index = get_annoy_index(word_embeddings_list)
    return annoy_index, word_index

# %%
# This might take minute or two (since it is a 400k corpus of 300d words).
word_annoy_index, word_index = generate_word_annoy_index(word_embeddings)

# %%
def generate_image_embeddings(image_paths, model):
    images = np.zeros(shape=images_vgg16.shape)
    image_path_index = dict(enumerate(image_paths))

    for ind, path in image_path_index.items():
        img_pil = image.load_img(path, target_size=images_vgg16.shape[1:-1])
        img_raw = image.img_to_array(img_pil)
        images[ind, :, :, :] = img_raw

    image_embeddings_list = model.predict(preprocess_input(images))
    return image_embeddings_list, image_path_index

def load_image_embeddings(vectors_filename, mapping_filename):
    image_embeddings = np.load("%s.npy" % vectors_filename)
    with open("%s.json" % mapping_filename) as f:
        image_path_index = json.load(f)
        return image_embeddings, {int(k): v for k, v in image_path_index.items()}

def save_image_embeddings(image_embeddings_filename,
                          image_embeddings,
                          mapping_filename, 
                          image_path_index):
    np.save("%s.npy" % image_embeddings_filename, image_embeddings)
    with open("%s.json" % mapping_filename, 'w') as index_file:
        json.dump(image_path_index, index_file)

# %%
def nearest_neighbors(vector, annoy_index, item_index, k=10):
    distances = annoy_index.get_nns_by_vector(vector, k, include_distances=True)
    return [[a, item_index[a], distances[1][i]] for i, a in enumerate(distances[0])]

# %%
def get_hybrid_embeddings(generate_embeddings=False):
    image_hybrid_embeddings_filepath = "./image_embeddings_with_history_30_epochs"
    image_path_indexes_filepath = "./image_path_indexes_with_history_30_epochs"
    # Generating embedding might take 5-10min.
    if generate_embeddings:
        image_hybrid_embeddings, image_path_index = \
            generate_image_embeddings(image_paths, hybrid_model)
        save_image_embeddings(image_hybrid_embeddings_filepath,
                              image_hybrid_embeddings,
                              image_path_indexes_filepath,
                              image_path_index)
        return image_hybrid_embeddings, image_path_index
    else:
        image_hybrid_embeddings, image_path_index = \
            load_image_embeddings(image_hybrid_embeddings_filepath, 
                                  image_path_indexes_filepath)
    return image_hybrid_embeddings, image_path_index

# %%
image_hybrid_embeddings, image_path_index = get_hybrid_embeddings(generate_embeddings=True)
image_annoy_index = get_annoy_index(image_hybrid_embeddings, number_of_trees=1000)

# %% [markdown]
# ### Utility functions

# %%
from IPython.display import Image
from IPython.display import HTML, display
import urllib.request

# %% [raw]
# # Assuming there are global variables (i.e. cells above did run):
# #   word_embeddings, word_annoy_index, word_index,
# #   hybrid_model, image_annoy_index, image_path_index

# %%
def display_similar_images(mean_embedding, image_path=None):
    closest_images = nearest_neighbors(mean_embedding, image_annoy_index, image_path_index)

    html_str = "<script>$('div.cell.selected').next().height(100);</script>\n"
    if image_path is not None:
        html_str += "<h1>Our input image</h1>"
        html_str += "<img src='%s'>" % image_path
        html_str += "<h1>Similar images</h1>"
    html_str += "<table>"

    for i in range(0, 5):
        left_cell = closest_images[2*i][1]
        html_str += "<tr><td><img src='%s'></td>" % left_cell
        right_cell = closest_images[2*i+1][1]
        html_str += "<td><img src='%s'></td></tr>" % right_cell
    html_str += "</table>\n"

    display(HTML(html_str))

def search_by_text(text):
    mean_embedding = np.mean([word_embeddings[word] for word in text.split()], axis=0)
    display_similar_images(mean_embedding)

def get_image_labels(image_path, display_image=False, k=10):
    if display_image:
        display(Image(filename=image_path))
    
    images = np.zeros(shape=(1,)+images_vgg16.shape[1:])
    img = image.load_img(image_path, target_size=images_vgg16.shape[1:-1])
    x_raw = image.img_to_array(img)
    images[0] = np.expand_dims(x_raw, axis=0)

    inputs = preprocess_input(images)

    image_features = hybrid_model.predict(inputs)[0]
    closest_labels = nearest_neighbors(image_features, word_annoy_index, word_index, k)
    return closest_labels

def search_similar_images(image_location, from_url=False):
    image_path = image_location
    if from_url:
        filename = image_location.split("/")[-1]
        urllib.request.urlretrieve(image_location, filename)
        image_path = filename

    closest_labels = [l for _, l, _ in get_image_labels(image_path)]
    mean_embedding = np.mean([word_embeddings[label] for label in closest_labels], axis=0)
    display_similar_images(mean_embedding, image_path)

# %% [markdown]
# # Evaluation

# %%
from termcolor import colored

# %%
def pretty_print_label_found(label, label_set, found = True):
    str = "label '{}' {} found in {}"
    is_found_str = "is" if found else "not"
    color = "green" if found else "red"
    print(colored(str.format(label, is_found_str, label_set), color))

def hit_at_k_metric(k, categories_list, image_paths, test_image_indices, verbose=False):
    count_hits = 0
    test_size = len(test_image_indices)

    for ind in test_image_indices:
        test_image_path = image_paths[ind]
        prediction = get_image_labels(test_image_path, False, k)
        predicted_image_labels = [x for _, x, _ in prediction]

        label = categories_list[ind]
        hit_found = False
        for ground_truth_value in label.split("_"):
            if ground_truth_value in predicted_image_labels:
                if verbose:
                    pretty_print_label_found(ground_truth_value, predicted_image_labels)
                hit_found = True
                break
        if verbose and not hit_found:
            pretty_print_label_found(label, predicted_image_labels, found=False)
        count_hits += hit_found

    print("hit@{} = {}/{}".format(k, count_hits, test_size))
    return count_hits/test_size

# %%
hit_at_k_metric(5, categories_list, image_paths, test_data[0].index, verbose=True)
# Out:
# label 'bus' not found in ['car', 'truck', 'vehicle', 'jeep', 'cars']
# label 'bird' not found in ['primate', 'duck', 'hen', 'gulls', 'ibis']
# label 'sofa' not found in ['overstuffed', 'fireplace', 'pillow', 'stool', 'oversized']
# label 'potted_plant' not found in ['succulent', 'berries', 'perennials', 'buds', 'figs']
# label 'car' not found in ['jeep', 'detonated', 'exploded', 'wrecked', 'bomb']
# label 'aeroplane' not found in ['vickers-armstrongs', 'zhizn', 'heavier-than-air', 'sukhoi', 'manufactory']
# label 'potted_plant' not found in ['pig', 'dog', 'cow', 'weeds', 'willow']
# label 'dining' is found in ['dining', 'tables', 'kitchen', 'chairs', 'rooms']
# label 'bicycle' not found in ['glass', 'glasses', 'folding', 'racks', 'chairs']
# label 'horse' not found in ['bred', 'bull', 'harness', 'ridden', '3-year']
# label 'person' not found in ['patient', 'fits', 'fit', 'perfectly', 'instance']
# label 'car' not found in ['jeep', 'detonated', 'bomb', 'exploded', 'suicide']
# label 'sheep' not found in ['pug', 'bobcat', 'crows', 'hog', 'grizzly']
# label 'dog' not found in ['puppy', 'pig', 'gorilla', 'turtle', 'squirrel']
# label 'motorbike' not found in ['skateboard', 'stuntman', 'skateboarding', 'witold', 'coming-of-age']
# label 'aeroplane' not found in ['troopship', 'machinist', 'singlehanded', 'gunboat', 'carrier-based']
# label 'train' not found in ['bus', 'subway', 'depart', 'metro', 'mumbai']
# label 'bicycle' not found in ['motorbike', 'bicycles', 'bikes', 'motorcycles', 'scooters']
# label 'chair' not found in ['bottle', 'glasses', 'glass', 'kitchen', 'chairs']
# label 'dog' not found in ['pets', 'lover', 'mom', 'dad', 'hungry']
# label 'horse' not found in ['117.4', 'torrington', 'gchq', 'gallstones', 'abalone']
# label 'bus' not found in ['commuter', 'derailed', 'convoy', 'ambushed', 'gunmen']
# label 'cat' not found in ['monkey', 'puppy', 'rabbits', 'rabbit', 'frog']
# label 'potted_plant' not found in ['tables', 'dining', 'cabinets', 'garden', 'shade']
# label 'motorbike' not found in ['rickshaw', 'benetton', 'fisichella', 'speedster', 'laval']
# label 'cat' not found in ['burglar', 'villain', 'spider', 'superman', 'sidekick']
# label 'person' not found in ['dog', 'somebody', 'joke', 'baby', 'framed']
# label 'bicycle' is found in ['bicycle', 'bike', 'riding', 'rode', 'ride']
# label 'cow' not found in ['bse', 'samadzai', 'torkan', 'flimm', 'salehi']
# label 'motorbike' is found in ['motorbike', 'scooter', 'attacker', 'firefighter', 'attackers']
# label 'chair' is found in ['chair', 'sitting', 'office', 'head', 'chairman']
# label 'person' not found in ['table', 'bottle', 'kitchen', 'chairs', 'dinner']
# label 'motorbike' is found in ['motorbike', 'motorcycles', 'minibus', 'scooters', 'bicycles']
# label 'sofa' not found in ['seated', 'woman', 'herself', 'sat', 'hers']
# label 'bird' not found in ['parakeet', 'warbler', 'civet', 'rookeries', 'blisters']
# label 'sofa' is found in ['sofa', 'cushions', 'pillows', 'reclining', 'drapes']
# label 'train' not found in ['recruit', 'recruits', 'teachers', 'instructors', 'recruiting']
# label 'boat' not found in ['boats', 'vessel', 'ship', 'ferry', 'ships']
# label 'cat' not found in ['gudjohnsen', 'eidur', 'mime', 'fearless', 'hermes']
# label 'dining' is found in ['dining', 'tables', 'chairs', 'kitchen', 'rooms']
# label 'cow' not found in ['aday', 'shadrin', 'fazekas', 'stute', 'ntra']
# label 'dog' not found in ['rat', 'author', 'companion', 'beloved', 'mom']
# label 'cow' not found in ['diseased', 'feta', 'composted', 'excrement', 'unpasteurized']
# label 'cow' is found in ['cow', 'sheep', 'cows', 'cattle', 'pigs']
# label 'cow' not found in ['borrelia', 'popplewell', 'darzi', 'molinas', 'hjertstedt']
# label 'bus' is found in ['bus', 'taxi', 'subway', 'cab', 'bicycle']
# label 'bird' not found in ['ducks', 'wild', 'eagle', 'dolphins', 'eagles']
# label 'cow' not found in ['diseased', 'unpasteurized', 'corned', 'excrement', 'scabies']
# label 'boat' not found in ['ferry', 'catamaran', 'piloting', 'sank', 'glider']
# label 'dining_table' not found in ['chair', 'summarized', 'guest', 'psychiatry', 'presided']
# label 'boat' is found in ['boat', 'vessel', 'ship', 'yacht', 'ferry']
# label 'sofa' not found in ['seated', 'sat', 'beside', 'upstairs', 'asleep']
# label 'boat' is found in ['boat', 'vessel', 'ship', 'barge', 'craft']
# label 'person' not found in ['someone', 'room', 'you', 'guy', 'your']
# label 'dining' is found in ['dining', 'tables', 'chairs', 'kitchen', 'sofa']
# label 'bird' is found in ['bird', 'goose', 'pig', 'rabbit', 'chicken']
# label 'boat' is found in ['boat', 'vessel', 'ship', 'tossed', 'craft']
# label 'dog' is found in ['dog', 'cat', 'cow', 'puppy', 'horse']
# label 'bus' not found in ['commuter', 'derailed', 'ambushed', 'convoy', 'gunmen']
# label 'dog' not found in ['pet', 'boy', 'guardian', 'lover', 'aunt']
# label 'cow' not found in ['goats', 'pasture', 'diseased', 'intestines', 'lesions']
# label 'bicycle' not found in ['motorbike', 'bicycles', 'bikes', 'motorcycles', 'scooters']
# label 'tv_monitor' not found in ['talk', 'closely', 'observers', 'calls', 'will']
# label 'boat' not found in ['ferry', 'boats', 'bus', 'train', 'vessel']
# label 'horse' is found in ['horse', 'cat', 'riding', 'rode', 'bike']
# label 'bicycle' not found in ['motorbike', 'bikes', 'bicycles', 'motorcycles', 'scooters']
# label 'tv_monitor' not found in ['tables', 'dining', 'cabinets', 'panels', 'screens']
# label 'tv_monitor' not found in ['definition', 'evaluate', 'observe', 'evaluating', 'assess']
# label 'bird' not found in ['flu', 'avian', 'migratory', 'h5n1', 'influenza']
# label 'plant' is found in ['plant', 'factory', 'car', 'cleaner', 'garbage']
# label 'cat' not found in ['shorthaired', 'puss', 'goku', 'berigan', 'zoot']
# label 'dog' not found in ['puppy', 'hound', 'kitten', 'rooster', 'kittens']
# label 'bird' is found in ['bird', 'fish', 'pig', 'sheep', 'chicken']
# label 'chair' not found in ['discussion', 'formal', 'rests', 'presented', 'topic']
# label 'train' not found in ['commuter', 'rail', 'railway', 'passenger', 'railroad']
# label 'chair' is found in ['chair', 'professor', 'chairwoman', 'emeritus', 'harvard']
# label 'sofa' not found in ['discussing', 'discussion', 'rests', 'constitution', 'afforded']
# label 'cow' not found in ['kizer', 'stirbois', 'laboratorium', 'capell', 'holyoake']
# label 'bus' is found in ['bus', 'passenger', 'drivers', 'travelling', 'traveling']
# label 'bicycle' not found in ['bikes', 'horseback', 'pedal', 'tailed', 'stocky']
# label 'bottle' not found in ['boat', 'vessel', 'ship', 'cat', 'gallons']
# label 'potted_plant' not found in ['factories', 'facilities', 'guangzhou', 'downtown', 'shandong']
# label 'dog' is found in ['dog', 'cat', 'cats', 'pig', 'puppy']
# label 'tv_monitor' not found in ['chat', 'taped', 'interviewer', 'mtv', 'broadcasters']
# label 'sheep' is found in ['sheep', 'cow', 'pig', 'horse', 'deer']
# label 'car' is found in ['car', 'truck', 'vehicle', 'cars', 'suv']
# label 'car' not found in ['cow', 'horse', 'bull', 'riding', 'racing']
# label 'bottle' not found in ['bicycle', 'car', 'motorcycle', 'motorbike', 'parked']
# label 'bus' is found in ['bus', 'passenger', 'drivers', 'accident', 'gunmen']
# label 'boat' is found in ['boat', 'vessel', 'ship', 'crew', 'sailors']
# label 'horse' is found in ['horse', 'horses', 'cow', 'sheep', 'cat']
# label 'chair' not found in ['sofa', 'dais', 'armchair', 'porch', 'downstairs']
# label 'person' not found in ['discussion', 'subject', 'manner', 'topic', 'context']
# label 'dining_table' not found in ['room', 'kitchen', 'dinner', 'breakfast', 'desk']
# label 'person' not found in ['horse', 'cow', 'horses', 'sheep', 'riding']
# label 'dining' is found in ['dining', 'glass', 'chat', 'bottle', 'restaurant']
# label 'boat' is found in ['boat', 'vessel', 'ship', 'ferry', 'yacht']
# label 'cow' not found in ['cows', 'calves', 'ailment', 'goose', 'cheese']
# label 'sofa' not found in ['glasses', 'looks', 'look', 'fits', 'frame']
# label 'boat' is found in ['boat', 'sank', 'submarine', 'jetliner', 'crashed']
# hit@5 = 29/100
# 0.29

# %%
hit_at_k_metric(10, categories_list, image_paths, test_data[0].index)
# Out:
# hit@10 = 36/100
# 0.36

# %%
hit_at_k_metric(20, categories_list, image_paths, test_data[0].index)
# Out:
# hit@20 = 44/100
# 0.44

# %%
def hierarchical_precision_at_k_metric(k, categories_list, image_paths, test_image_indices):
    count_hits = 0
    total_matches = 0
    test_size = len(test_image_indices)

    for ind in test_image_indices:
        # Hybrid model's k predictions
        test_image_path = image_paths[ind]
        prediction = get_image_labels(test_image_path, False, k)
        predicted_image_labels = [x for _, x, _ in prediction]

        # Ground truth list (k nearest labels in GloVe)
        label_embedding = get_word_embedding(categories_list[ind], word_embeddings)
        nearest_k = nearest_neighbors(label_embedding, word_annoy_index, word_index, k)
        ground_truth_list = [x for _, x, _ in nearest_k]
        
        # Calculate mean precision
        common = set(predicted_image_labels).intersection(ground_truth_list)
        if common:
            total_matches += len(common)
            count_hits += 1
    print("non-empty intersections: {}/{}\n".format(count_hits, test_size))
    precision = total_matches/(test_size * k)
    print("PRECISION = 1/N * SUM(intersection_size_for_ith_image / k)")
    print("          = SUM(intersection_size_for_ith_image)/(N*k)")
    print("          = {}".format(precision))
    print("where N={}, k={}, SUM(intersection_size_for_ith_image)={}".format(test_size, k, total_matches))
    return precision

# %%
hierarchical_precision_at_k_metric(
    5, categories_list, image_paths, test_data[0].index)
# Out:
# non-empty intersections: 41/100
#
# PRECISION = 1/N * SUM(intersection_size_for_ith_image / k)
#           = SUM(intersection_size_for_ith_image)/(N*k)
#           = 0.182
# where N=100, k=5, SUM(intersection_size_for_ith_image)=91
# 0.182

# %%
hierarchical_precision_at_k_metric(
    10, categories_list, image_paths, test_data[0].index)
# Out:
# non-empty intersections: 57/100
#
# PRECISION = 1/N * SUM(intersection_size_for_ith_image / k)
#           = SUM(intersection_size_for_ith_image)/(N*k)
#           = 0.199
# where N=100, k=10, SUM(intersection_size_for_ith_image)=199
# 0.199

# %%
hierarchical_precision_at_k_metric(
    20, categories_list, image_paths, test_data[0].index)
# Out:
# non-empty intersections: 72/100
#
# PRECISION = 1/N * SUM(intersection_size_for_ith_image / k)
#           = SUM(intersection_size_for_ith_image)/(N*k)
#           = 0.2195
# where N=100, k=20, SUM(intersection_size_for_ith_image)=439
# 0.2195

# %% [markdown]
# # DEMO

# %% [markdown]
# *Identifying labels on some pictures from the dataset:*

# %%
get_image_labels(image_paths[222], display_image=True)
# Out:
# [[1277, 'cars', 0.9347394108772278],
#  [1634, 'vehicles', 0.9842756986618042],
#  [12238, 'jeep', 1.039428949356079],
#  [4575, 'buses', 1.0758854150772095],
#  [4322, 'exploded', 1.0988658666610718],
#  [1211, 'bomb', 1.1082980632781982],
#  [2426, 'blast', 1.1108413934707642],
#  [3597, 'trucks', 1.1139962673187256],
#  [9652, 'detonated', 1.117742896080017],
#  [1523, 'suicide', 1.1263397932052612]]

# %%
get_image_labels(image_paths[368], display_image=True)
# Out:
# [[4802, 'cnn', 1.0578941106796265],
#  [172, 'news', 1.110846996307373],
#  [3874, 'programming', 1.1327930688858032],
#  [1170, 'web', 1.1369760036468506],
#  [925, 'internet', 1.1438688039779663],
#  [9986, 'websites', 1.1521581411361694],
#  [6864, 'subscribers', 1.1574898958206177],
#  [1292, 'online', 1.1626341342926025],
#  [8927, 'advertisements', 1.1650054454803467],
#  [1491, 'newspapers', 1.167678952217102]]

# %% [markdown]
# *Searching for specific category/label:*

# %%
search_by_text("aeroplane")
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <table><tr><td><img src='./dataset/aeroplane/2008_005907.jpg'></td><td><img src='./dataset/aeroplane/2008_001468.jpg'></td></tr><tr><td><img src='./dataset/aeroplane/2008_006401.jpg'></td><td><img src='./dataset/aeroplane/2008_000716.jpg'></td></tr><tr><td><img src='./dataset/aeroplane/2008_001801.jpg'></td><td><img src='./dataset/aeroplane/2008_004165.jpg'></td></tr><tr><td><img src='./dataset/aeroplane/2008_002454.jpg'></td><td><img src='./dataset/aeroplane/2008_008044.jpg'></td></tr><tr><td><img src='./dataset/aeroplane/2008_006933.jpg'></td><td><img src='./dataset/aeroplane/2008_001971.jpg'></td></tr></table>

# %% [markdown]
# *Searching for categories that are not in image dataset:*

# %%
search_by_text("avian")
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <table><tr><td><img src='./dataset/bird/2008_006667.jpg'></td><td><img src='./dataset/bird/2008_007003.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_008490.jpg'></td><td><img src='./dataset/bird/2008_005774.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_006186.jpg'></td><td><img src='./dataset/bird/2008_006281.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_003484.jpg'></td><td><img src='./dataset/bird/2008_008002.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_003222.jpg'></td><td><img src='./dataset/bird/2008_005757.jpg'></td></tr></table>

# %%
search_by_text("ocean")
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <table><tr><td><img src='./dataset/boat/2008_006654.jpg'></td><td><img src='./dataset/car/2008_007346.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_003951.jpg'></td><td><img src='./dataset/boat/2008_005923.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_001858.jpg'></td><td><img src='./dataset/boat/2008_001202.jpg'></td></tr><tr><td><img src='./dataset/person/2008_002283.jpg'></td><td><img src='./dataset/boat/2008_005959.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_001041.jpg'></td><td><img src='./dataset/boat/2008_006720.jpg'></td></tr></table>

# %%
search_by_text("street")
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <table><tr><td><img src='./dataset/bus/2008_005676.jpg'></td><td><img src='./dataset/sheep/2008_000915.jpg'></td></tr><tr><td><img src='./dataset/car/2008_004080.jpg'></td><td><img src='./dataset/bus/2008_005074.jpg'></td></tr><tr><td><img src='./dataset/car/2008_006220.jpg'></td><td><img src='./dataset/car/2008_006762.jpg'></td></tr><tr><td><img src='./dataset/car/2008_008338.jpg'></td><td><img src='./dataset/car/2008_004858.jpg'></td></tr><tr><td><img src='./dataset/car/2008_006087.jpg'></td><td><img src='./dataset/car/2008_006649.jpg'></td></tr></table>

# %% [markdown]
# *Achieving more complex queries by combining words:*

# %%
search_by_text("horse jockey")
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <table><tr><td><img src='./dataset/horse/2008_003805.jpg'></td><td><img src='./dataset/horse/2008_005498.jpg'></td></tr><tr><td><img src='./dataset/horse/2008_002666.jpg'></td><td><img src='./dataset/horse/2008_008318.jpg'></td></tr><tr><td><img src='./dataset/horse/2008_006096.jpg'></td><td><img src='./dataset/horse/2008_002459.jpg'></td></tr><tr><td><img src='./dataset/horse/2008_006991.jpg'></td><td><img src='./dataset/horse/2008_003447.jpg'></td></tr><tr><td><img src='./dataset/horse/2008_004470.jpg'></td><td><img src='./dataset/horse/2008_003283.jpg'></td></tr></table>

# %%
search_by_text("bird near water")
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <table><tr><td><img src='./dataset/bird/2008_005774.jpg'></td><td><img src='./dataset/bird/2008_004783.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_002399.jpg'></td><td><img src='./dataset/bird/2008_000095.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_001020.jpg'></td><td><img src='./dataset/bird/2008_008347.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_007752.jpg'></td><td><img src='./dataset/bird/2008_001829.jpg'></td></tr><tr><td><img src='./dataset/bird/2008_004452.jpg'></td><td><img src='./dataset/bird/2008_004362.jpg'></td></tr></table>

# %% [markdown]
# *Since we are able to identify labels on an image, we can perform search by image:*

# %%
search_similar_images(image_paths[test_data[0].index[3]])
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <h1>Our input image</h1><img src='./dataset/potted_plant/2008_004634.jpg'><h1>Similar images</h1><table><tr><td><img src='./dataset/potted_plant/2008_001862.jpg'></td><td><img src='./dataset/potted_plant/2008_004171.jpg'></td></tr><tr><td><img src='./dataset/potted_plant/2008_000491.jpg'></td><td><img src='./dataset/potted_plant/2008_007226.jpg'></td></tr><tr><td><img src='./dataset/potted_plant/2008_004634.jpg'></td><td><img src='./dataset/potted_plant/2008_007042.jpg'></td></tr><tr><td><img src='./dataset/potted_plant/2008_001460.jpg'></td><td><img src='./dataset/potted_plant/2008_007831.jpg'></td></tr><tr><td><img src='./dataset/potted_plant/2008_007525.jpg'></td><td><img src='./dataset/potted_plant/2008_006112.jpg'></td></tr></table>

# %%
search_similar_images(image_paths[test_data[0].index[6]])
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <h1>Our input image</h1><img src='./dataset/potted_plant/2008_007621.jpg'><h1>Similar images</h1><table><tr><td><img src='./dataset/potted_plant/2008_001078.jpg'></td><td><img src='./dataset/potted_plant/2008_007621.jpg'></td></tr><tr><td><img src='./dataset/dog/2008_001895.jpg'></td><td><img src='./dataset/dog/2008_005798.jpg'></td></tr><tr><td><img src='./dataset/dog/2008_004498.jpg'></td><td><img src='./dataset/cow/2008_004841.jpg'></td></tr><tr><td><img src='./dataset/dog/2008_000620.jpg'></td><td><img src='./dataset/potted_plant/2008_003665.jpg'></td></tr><tr><td><img src='./dataset/potted_plant/2008_000491.jpg'></td><td><img src='./dataset/cat/2008_004328.jpg'></td></tr></table>

# %% [markdown]
# *The same goes for images outside of the dataset*

# %%
search_similar_images('./demo_images/modern-interior-design-home-preview.jpg')
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <h1>Our input image</h1><img src='./demo_images/modern-interior-design-home-preview.jpg'><h1>Similar images</h1><table><tr><td><img src='./dataset/chair/2008_004985.jpg'></td><td><img src='./dataset/tv_monitor/2008_001772.jpg'></td></tr><tr><td><img src='./dataset/tv_monitor/2008_007282.jpg'></td><td><img src='./dataset/dining_table/2008_007097.jpg'></td></tr><tr><td><img src='./dataset/sofa/2008_001869.jpg'></td><td><img src='./dataset/chair/2008_007949.jpg'></td></tr><tr><td><img src='./dataset/dining_table/2008_003753.jpg'></td><td><img src='./dataset/chair/2008_003504.jpg'></td></tr><tr><td><img src='./dataset/chair/2008_002481.jpg'></td><td><img src='./dataset/tv_monitor/2008_004665.jpg'></td></tr></table>

# %%
search_similar_images('./demo_images/death-railway-4008940_960_720.jpg')
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <h1>Our input image</h1><img src='./demo_images/death-railway-4008940_960_720.jpg'><h1>Similar images</h1><table><tr><td><img src='./dataset/bus/2008_008043.jpg'></td><td><img src='./dataset/bus/2008_004844.jpg'></td></tr><tr><td><img src='./dataset/bus/2008_005933.jpg'></td><td><img src='./dataset/train/2008_004914.jpg'></td></tr><tr><td><img src='./dataset/train/2008_000343.jpg'></td><td><img src='./dataset/bus/2008_008549.jpg'></td></tr><tr><td><img src='./dataset/train/2008_007759.jpg'></td><td><img src='./dataset/bus/2008_003924.jpg'></td></tr><tr><td><img src='./dataset/car/2008_000982.jpg'></td><td><img src='./dataset/bus/2008_007969.jpg'></td></tr></table>

# %%
search_similar_images('./demo_images/moor-moorland-grasses-wetland-nature-conservation-nature-reserve-nature-landscape-wetlands.jpg')
# Out:
# <script>$('div.cell.selected').next().height(100);</script>
# <h1>Our input image</h1><img src='./demo_images/moor-moorland-grasses-wetland-nature-conservation-nature-reserve-nature-landscape-wetlands.jpg'><h1>Similar images</h1><table><tr><td><img src='./dataset/car/2008_007346.jpg'></td><td><img src='./dataset/boat/2008_006720.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_006654.jpg'></td><td><img src='./dataset/boat/2008_000437.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_001858.jpg'></td><td><img src='./dataset/boat/2008_005959.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_002482.jpg'></td><td><img src='./dataset/boat/2008_007841.jpg'></td></tr><tr><td><img src='./dataset/boat/2008_003951.jpg'></td><td><img src='./dataset/boat/2008_002850.jpg'></td></tr></table>
